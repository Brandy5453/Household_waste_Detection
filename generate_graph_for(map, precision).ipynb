# %%
import matplotlib.pyplot as plt

# Precision, Recall, and F1-score at threshold 0.50
precision_50 = 0.23841089367866516
recall_50 = 0.9786850214004517
f1_50 = 0.34156459271907806

# Create a bar graph to visualize these metrics
metrics = ['Precision@0.50', 'Recall@0.50', 'F1@0.50']
values = [precision_50, recall_50, f1_50]

plt.figure(figsize=(8, 5))
plt.bar(metrics, values, color=['blue', 'green', 'red'])
plt.ylabel('Score')
plt.title('Performance Metrics at Threshold 0.50')
plt.ylim(0, 1.0)  # Set the y-axis limit to a range between 0 and 1
plt.show()
# This code will create a bar graph that displays the values of Precision@0.50, Recall@0.50, and F1@0.50. You can adjust the colors, figure size, and other styling options to suit your preferences.

# Please note that this graph shows these metrics at a fixed threshold of 0.50. To create a confusion matrix, you would typically need the model's predictions and the corresponding ground truth labels for a set of test data. If you have access to those values, you can generate a confusion matrix as described in the previous response.
